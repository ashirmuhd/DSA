# %% [markdown]
# <a href="https://colab.research.google.com/github/ashirmuhd/DSA/blob/main/get_data_from_diff_sources_casestud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests
import requests
import pandas as pd
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.7.9)

# %% [markdown]
# #Step 1

# %%
#1
launch_url = "https://api.spacexdata.com/v4/launches"
launch_data = requests.get(launch_url).json()

# %%
#2
df_launch = pd.DataFrame(launch_data)[['name', 'date_utc', 'success', 'details', 'rocket']]
df_launch
# Out:
#                        name                  date_utc success  \
# 0                 FalconSat  2006-03-24T22:30:00.000Z   False
# 1                   DemoSat  2007-03-21T01:10:00.000Z   False
# 2               Trailblazer  2008-08-03T03:34:00.000Z   False
# 3                    RatSat  2008-09-28T23:15:00.000Z    True
# 4                  RazakSat  2009-07-13T03:35:00.000Z    True
# ..                      ...                       ...     ...
# 200           Transporter-6  2022-12-01T00:00:00.000Z    None
# 201                   TTL-1  2022-12-01T00:00:00.000Z    None
# 202  WorldView Legion 1 & 2  2022-12-01T00:00:00.000Z    None
# 203     Viasat-3 & Arcturus  2022-12-01T00:00:00.000Z    None
# 204          O3b mPower 3.4  2022-12-01T00:00:00.000Z    None
#
#                                                details  \
# 0     Engine failure at 33 seconds and loss of vehicle
# 1    Successful first stage burn and transition to ...
# 2    Residual stage 1 thrust led to collision betwe...
# 3    Ratsat was carried to orbit on the first succe...
# 4                                                 None
# ..                                                 ...
# 200                                               None
# 201                                               None
# 202                                               None
# 203                                               None
# 204                                               None
#
#                        rocket
# 0    5e9d0d95eda69955f709d1eb
# 1    5e9d0d95eda69955f709d1eb
# 2    5e9d0d95eda69955f709d1eb
# 3    5e9d0d95eda69955f709d1eb
# 4    5e9d0d95eda69955f709d1eb
# ..                        ...
# 200  5e9d0d95eda69973a809d1ec
# 201  5e9d0d95eda69973a809d1ec
# 202  5e9d0d95eda69973a809d1ec
# 203  5e9d0d95eda69974db09d1ed
# 204  5e9d0d95eda69973a809d1ec
#
# [205 rows x 5 columns]

# %%
#3
df_launch['date_utc'] = pd.to_datetime(df_launch['date_utc'])
df_launch['year'] = df_launch['date_utc'].dt.year
df_launch.head()
# Out:
#           name                  date_utc success  \
# 0    FalconSat 2006-03-24 22:30:00+00:00   False
# 1      DemoSat 2007-03-21 01:10:00+00:00   False
# 2  Trailblazer 2008-08-03 03:34:00+00:00   False
# 3       RatSat 2008-09-28 23:15:00+00:00    True
# 4     RazakSat 2009-07-13 03:35:00+00:00    True
#
#                                              details  \
# 0   Engine failure at 33 seconds and loss of vehicle
# 1  Successful first stage burn and transition to ...
# 2  Residual stage 1 thrust led to collision betwe...
# 3  Ratsat was carried to orbit on the first succe...
# 4                                               None
#
#                      rocket  year
# 0  5e9d0d95eda69955f709d1eb  2006
# 1  5e9d0d95eda69955f709d1eb  2007
# 2  5e9d0d95eda69955f709d1eb  2008
# 3  5e9d0d95eda69955f709d1eb  2008
# 4  5e9d0d95eda69955f709d1eb  2009

# %% [markdown]
# #Step 2

# %%
meta_url = "https://api.spacexdata.com/v4/rockets"
meta_data =  requests.get(meta_url).json()

# %%
df_meta = pd.DataFrame(meta_data)[['id', 'name', 'type', 'active','stages' ]]
df_meta.rename(columns={'id': 'rocket'}, inplace=True)
df_meta.head()
# Out:
#                      rocket          name    type  active  stages
# 0  5e9d0d95eda69955f709d1eb      Falcon 1  rocket   False       2
# 1  5e9d0d95eda69973a809d1ec      Falcon 9  rocket    True       2
# 2  5e9d0d95eda69974db09d1ed  Falcon Heavy  rocket    True       2
# 3  5e9d0d96eda699382d09d1ee      Starship  rocket   False       2

# %% [markdown]
# #Step 3

# %%
#1
df_merged = pd.merge(df_launch, df_meta, on='rocket', how='left')
df_merged
# Out:
#                      name_x                  date_utc success  \
# 0                 FalconSat 2006-03-24 22:30:00+00:00   False
# 1                   DemoSat 2007-03-21 01:10:00+00:00   False
# 2               Trailblazer 2008-08-03 03:34:00+00:00   False
# 3                    RatSat 2008-09-28 23:15:00+00:00    True
# 4                  RazakSat 2009-07-13 03:35:00+00:00    True
# ..                      ...                       ...     ...
# 200           Transporter-6 2022-12-01 00:00:00+00:00    None
# 201                   TTL-1 2022-12-01 00:00:00+00:00    None
# 202  WorldView Legion 1 & 2 2022-12-01 00:00:00+00:00    None
# 203     Viasat-3 & Arcturus 2022-12-01 00:00:00+00:00    None
# 204          O3b mPower 3.4 2022-12-01 00:00:00+00:00    None
#
#                                                details  \
# 0     Engine failure at 33 seconds and loss of vehicle
# 1    Successful first stage burn and transition to ...
# 2    Residual stage 1 thrust led to collision betwe...
# 3    Ratsat was carried to orbit on the first succe...
# 4                                                 None
# ..                                                 ...
# 200                                               None
# 201                                               None
# 202                                               None
# 203                                               None
# 204                                               None
#
#                        rocket  year        name_y    type  active  stages
# 0    5e9d0d95eda69955f709d1eb  2006      Falcon 1  rocket   False       2
# 1    5e9d0d95eda69955f709d1eb  2007      Falcon 1  rocket   False       2
# 2    5e9d0d95eda69955f709d1eb  2008      Falcon 1  rocket   False       2
# 3    5e9d0d95eda69955f709d1eb  2008      Falcon 1  rocket   False       2
# 4    5e9d0d95eda69955f709d1eb  2009      Falcon 1  rocket   False       2
# ..                        ...   ...           ...     ...     ...     ...
# 200  5e9d0d95eda69973a809d1ec  2022      Falcon 9  rocket    True       2
# 201  5e9d0d95eda69973a809d1ec  2022      Falcon 9  rocket    True       2
# 202  5e9d0d95eda69973a809d1ec  2022      Falcon 9  rocket    True       2
# 203  5e9d0d95eda69974db09d1ed  2022  Falcon Heavy  rocket    True       2
# 204  5e9d0d95eda69973a809d1ec  2022      Falcon 9  rocket    True       2
#
# [205 rows x 10 columns]

# %% [markdown]
# #Step 4

# %%
#1
import random
import numpy as np


countries = ['USA', 'Russia', 'India', 'China', 'France']
df_merged['country'] = np.random.choice(countries, size=len(df_merged))
df_merged['country']
# Out:
# 0      Russia
# 1         USA
# 2         USA
# 3       India
# 4         USA
#         ...
# 200    France
# 201    France
# 202       USA
# 203     India
# 204    France
# Name: country, Length: 205, dtype: object

# %% [markdown]
# #Step 5

# %%
#1

import sqlite3
conn = sqlite3.connect("spacex_launches.db")
df_merged.to_sql("launches", conn, if_exists="replace", index=False)
# Out:
# 205

# %% [markdown]
# #Step 6

# %%
#1
query1 = "SELECT country, COUNT(*) as num_launches FROM launches GROUP BY country"
print(pd.read_sql(query1, conn))
# Out:
#   country  num_launches
# 0   China            36
# 1  France            45
# 2   India            47
# 3  Russia            37
# 4     USA            40

# %%
#2
query2 = "SELECT year, COUNT(*) as num_launches FROM launches GROUP BY year ORDER BY num_launches DESC LIMIT 1"
print(pd.read_sql(query2, conn))
# Out:
#    year  num_launches
# 0  2022            62

# %%
#3
query3 = "SELECT name_x as missons, COUNT(*) as launch_count FROM launches GROUP BY name_x ORDER BY launch_count DESC LIMIT 5"
print(pd.read_sql(query3, conn))
# Out:
#                      missons  launch_count
# 0  ispace Mission 1 & Rashid             1
# 1                       ZUMA             1
# 2     WorldView Legion 1 & 2             1
# 3        Viasat-3 & Arcturus             1
# 4                    USSF-44             1
