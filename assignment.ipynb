# %% [markdown]
# <a href="https://colab.research.google.com/github/ashirmuhd/DSA/blob/main/assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/iris.xls')
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
df.mean(numeric_only=True)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
df.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns



df.hist(figsize=(10, 8), bins=15)
plt.suptitle("Histogram ", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='SL', y='SW', hue='Classification', data=df, s=80)
plt.title("Scatter Plot: Sepal Length vs Sepal Width")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Classification', y='SL', data=df)
plt.title("Boxplot of Sepal Length by Species")
plt.show()

# %%
sns.pairplot(df, hue='Classification')
plt.suptitle("Pairplot of Iris Dataset", fontsize=16)
plt.show()
