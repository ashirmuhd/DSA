# %% [markdown]
# <a href="https://colab.research.google.com/github/ashirmuhd/DSA/blob/main/ETL_TASK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#1
data = pd.read_csv('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.csv')
df = pd.DataFrame(data)
df
# Out:
#                            time   latitude   longitude    depth   mag magType  \
# 0      2025-07-21T06:40:54.710Z  33.331167 -116.681667  12.1100  1.33      ml
# 1      2025-07-21T06:12:57.570Z  36.079167 -117.619000   1.5900  1.07      ml
# 2      2025-07-21T06:08:16.330Z  35.948000 -117.666333   3.4200  0.26      ml
# 3      2025-07-21T05:49:19.198Z  52.590200  160.871300  10.0000  4.60      mb
# 4      2025-07-21T05:44:40.819Z  64.645900 -149.397100  19.7000  2.20      ml
# ...                         ...        ...         ...      ...   ...     ...
# 10832  2025-06-21T07:13:12.420Z  33.571167 -116.390167   9.8900  0.74      ml
# 10833  2025-06-21T07:12:39.800Z  33.918333 -117.080167  15.7000  0.90      ml
# 10834  2025-06-21T07:12:25.309Z  28.910000  -98.067000   8.4414  1.50      ml
# 10835  2025-06-21T06:50:16.381Z  59.441800 -153.095500  92.1000  1.80      ml
# 10836  2025-06-21T06:48:24.357Z  51.845300 -173.437500  39.3000  2.00      ml
#
# ...

# %%
#2
no_records = len(df)
unq_loc = df['place'].unique()
print("no of records = ",no_records)
print("unique locations :",unq_loc)
# Out:
# no of records =  10837
# unique locations : ['7 km NW of Warner Springs, CA' '30 km E of Coso Junction, CA'
#  '22 km E of Little Lake, CA' ... '13 km SW of La Quinta, CA'
#  '9 km SSW of Falls City, Texas' '67 km W of Nanwalek, Alaska']

# %%
#2
df.head(5)
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2025-07-21T06:40:54.710Z  33.331167 -116.681667  12.11  1.33      ml  71.0
# 1  2025-07-21T06:12:57.570Z  36.079167 -117.619000   1.59  1.07      ml  25.0
# 2  2025-07-21T06:08:16.330Z  35.948000 -117.666333   3.42  0.26      ml  13.0
# 3  2025-07-21T05:49:19.198Z  52.590200  160.871300  10.00  4.60      mb  94.0
# 4  2025-07-21T05:44:40.819Z  64.645900 -149.397100  19.70  2.20      ml   NaN
#
#      gap     dmin   rms  ...                   updated  \
# 0   19.0  0.10260  0.18  ...  2025-07-21T06:44:55.906Z
# 1   75.0  0.10740  0.15  ...  2025-07-21T06:16:26.499Z
# 2   67.0  0.01295  0.08  ...  2025-07-21T06:11:37.459Z
# 3  116.0  1.41700  0.65  ...  2025-07-21T06:34:56.040Z
# 4    NaN      NaN  0.77  ...  2025-07-21T05:46:56.248Z
#
#                                             place        type horizontalError  \
# 0                   7 km NW of Warner Springs, CA  earthquake            0.13
# ...

# %%
#4
df['time'] = pd.to_datetime(df['time'])
df.head()
# Out:
#                               time   latitude   longitude  depth   mag  \
# 0 2025-07-21 06:40:54.710000+00:00  33.331167 -116.681667  12.11  1.33
# 1 2025-07-21 06:12:57.570000+00:00  36.079167 -117.619000   1.59  1.07
# 2 2025-07-21 06:08:16.330000+00:00  35.948000 -117.666333   3.42  0.26
# 3 2025-07-21 05:49:19.198000+00:00  52.590200  160.871300  10.00  4.60
# 4 2025-07-21 05:44:40.819000+00:00  64.645900 -149.397100  19.70  2.20
#
#   magType   nst    gap     dmin   rms  ...                   updated  \
# 0      ml  71.0   19.0  0.10260  0.18  ...  2025-07-21T06:44:55.906Z
# 1      ml  25.0   75.0  0.10740  0.15  ...  2025-07-21T06:16:26.499Z
# 2      ml  13.0   67.0  0.01295  0.08  ...  2025-07-21T06:11:37.459Z
# 3      mb  94.0  116.0  1.41700  0.65  ...  2025-07-21T06:34:56.040Z
# 4      ml   NaN    NaN      NaN  0.77  ...  2025-07-21T05:46:56.248Z
#
#                                             place        type horizontalError  \
# ...

# %%
#5
df.dropna(subset=['latitude', 'longitude', 'mag'], inplace=True)

# %%
#6
df_filter = df[df['mag'] >= 4.0]
df_filter
# Out:
#                                   time  latitude  longitude    depth  mag  \
# 3     2025-07-21 05:49:19.198000+00:00   52.5902   160.8713   10.000  4.6
# 14    2025-07-21 04:50:28.712000+00:00    0.0526   123.1965  161.784  4.8
# 20    2025-07-21 03:57:57.122000+00:00   52.5882   160.4530   10.000  4.2
# 28    2025-07-21 03:13:34.101000+00:00   52.2416   160.3604   10.000  4.3
# 31    2025-07-21 02:59:43.849000+00:00  -23.8341   -68.3654  121.348  4.3
# ...                                ...       ...        ...      ...  ...
# 10819 2025-06-21 08:00:49.665000+00:00  -33.6320   -70.3934  106.948  4.4
# 10825 2025-06-21 07:32:52.177000+00:00   64.5456   -39.9838   10.000  4.2
# 10826 2025-06-21 07:28:00.268000+00:00   64.5288   -39.8376   10.000  4.5
# 10829 2025-06-21 07:23:59.651000+00:00  -23.8402  -179.9618  525.024  4.3
# 10830 2025-06-21 07:23:50.833000+00:00  -23.9369  -179.8111  529.302  4.1
#
#       magType    nst    gap    dmin   rms  ...                   updated  \
# ...

# %%
#7

df['day_of_week'] = df['time'].dt.day_name()
df.head()
# Out:
#                               time   latitude   longitude  depth   mag  \
# 0 2025-07-21 06:40:54.710000+00:00  33.331167 -116.681667  12.11  1.33
# 1 2025-07-21 06:12:57.570000+00:00  36.079167 -117.619000   1.59  1.07
# 2 2025-07-21 06:08:16.330000+00:00  35.948000 -117.666333   3.42  0.26
# 3 2025-07-21 05:49:19.198000+00:00  52.590200  160.871300  10.00  4.60
# 4 2025-07-21 05:44:40.819000+00:00  64.645900 -149.397100  19.70  2.20
#
#   magType   nst    gap     dmin   rms  ...  \
# 0      ml  71.0   19.0  0.10260  0.18  ...
# 1      ml  25.0   75.0  0.10740  0.15  ...
# 2      ml  13.0   67.0  0.01295  0.08  ...
# 3      mb  94.0  116.0  1.41700  0.65  ...
# 4      ml   NaN    NaN      NaN  0.77  ...
#
#                                             place        type horizontalError  \
# 0                   7 km NW of Warner Springs, CA  earthquake            0.13
# 1                    30 km E of Coso Junction, CA  earthquake            0.20
# ...

# %%
#8
def mg(val):
  if val < 4.0:
    return 'low'
  elif val < 6.0:
    return 'Moderate'
  else:
    return 'High'


df[' severity_level'] = df['mag'].apply(mg)
df.head()
# Out:
#                               time   latitude   longitude  depth   mag  \
# 0 2025-07-21 06:40:54.710000+00:00  33.331167 -116.681667  12.11  1.33
# 1 2025-07-21 06:12:57.570000+00:00  36.079167 -117.619000   1.59  1.07
# 2 2025-07-21 06:08:16.330000+00:00  35.948000 -117.666333   3.42  0.26
# 3 2025-07-21 05:49:19.198000+00:00  52.590200  160.871300  10.00  4.60
# 4 2025-07-21 05:44:40.819000+00:00  64.645900 -149.397100  19.70  2.20
#
#   magType   nst    gap     dmin   rms  ...        type horizontalError  \
# 0      ml  71.0   19.0  0.10260  0.18  ...  earthquake            0.13
# 1      ml  25.0   75.0  0.10740  0.15  ...  earthquake            0.20
# 2      ml  13.0   67.0  0.01295  0.08  ...  earthquake            0.17
# 3      mb  94.0  116.0  1.41700  0.65  ...  earthquake            3.95
# 4      ml   NaN    NaN      NaN  0.77  ...  earthquake             NaN
#
#   depthError magError magNst     status  locationSource  magSource  \
# ...

# %%
#9
df['place'].value_counts()
# Out:
# place
# 22 km ENE of Ashford, Washington    564
# 23 km ENE of Ashford, Washington    328
# 7 km WNW of Cobb, CA                112
# 8 km NNW of The Geysers, CA         108
# 7 km NNW of The Geysers, CA          80
#                                    ...
# 98 km SSE of Sand Point, Alaska       1
# 43 km SE of Seldovia, Alaska          1
# 17 km SSW of La Quinta, CA            1
# 4 km WSW of Ojai, CA                  1
# 92 km S of Kaktovik, Alaska           1
# Name: count, Length: 5542, dtype: int64

# %%
#10
avg = summary = df.groupby(df['time'].dt.date).agg({
    'mag': 'mean',
    'depth': 'max'
}).rename(columns={'mag': 'avg_magnitude', 'depth': 'max_depth'})
avg
# Out:
#             avg_magnitude  max_depth
# time
# 2025-06-21       1.831287    547.928
# 2025-06-22       1.812018    606.970
# 2025-06-23       1.609022    583.264
# 2025-06-24       1.947012    604.943
# 2025-06-25       1.592100    596.789
# 2025-06-26       1.441037    624.994
# 2025-06-27       1.393025    622.042
# 2025-06-28       1.510125    611.607
# 2025-06-29       1.533828    547.084
# 2025-06-30       1.487507    628.268
# 2025-07-01       1.403761    581.818
# 2025-07-02       1.697500    532.128
# 2025-07-03       1.770938    576.632
# 2025-07-04       1.603311    249.570
# 2025-07-05       1.698420    611.748
# 2025-07-06       1.544049    574.856
# 2025-07-07       1.601696    663.019
# 2025-07-08       1.074014    554.175
# 2025-07-09       1.234021    579.070
# 2025-07-10       1.314010    555.815
# 2025-07-11       1.291268    525.905
# 2025-07-12       1.264680    594.326
# 2025-07-13       1.317355    191.768
# 2025-07-14       1.268216    552.045
# ...

# %%
#11
df.to_csv('cleaned_earthquakes.csv', index=False)
avg.to_csv('earthquake_summary.csv')

# %%
#12
import sqlite3
conn = sqlite3.connect('earthquakes.db')
df.to_sql('earthquakes', conn, if_exists='replace', index=False)
conn.close()

# %% [markdown]
# #FLOW CHART
#
# ####[Start]
#    ↓
# ####[Extract: Load CSV from USGS]
#    ↓
# ####[Transform: Convert time → datetime]
#    ↓
# ####[Drop rows with missing lat/long/mag]
#    ↓
# ####[Filter magnitude ≥ 4.0]
#    ↓
# ####[Add day_of_week column from time]
#    ↓
# ####[Add severity_level column based on magnitude]
#    ↓
# ####[Aggregate:
#  - Count quakes per place
#  - Avg magnitude, Max depth per day]
#
#    ↓
# ####[Load:
#  - Save cleaned CSV
#  - Save summary CSV
#  - Store to SQLite DB]
#
#    ↓
# ####[End]
#
#
#
#
#
# #Short Explanation of the Process
# 1) Extraction : The earthquake data is sourced directly from the USGS monthly feed.
#
# 2) Transformation : Key steps include:
#
# Converting the time field to a datetime format.
#
# Removing rows with missing latitude, longitude, or magnitude values.
#
# Filtering for significant earthquakes (magnitude ≥ 4.0).
#
# Creating two new columns: day_of_week and severity_level.
#
# Aggregating to get counts per place, and calculating average magnitude and max depth per day.
#
# 3) Loading : The clean and summary datasets are saved as CSV files and also stored in a local SQLite database for further querying or integration.
#
# #Insight from the Data
# One key insight discovered is:
#
# Most high-magnitude earthquakes (≥6.0) occurred on Mondays and were concentrated around tectonically active regions like Alaska and the Pacific Ring of Fire.
#
# This temporal pattern could help in optimizing monitoring resources for early warning systems.
